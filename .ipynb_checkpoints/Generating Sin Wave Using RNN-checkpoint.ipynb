# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,50,501)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
df = pd.DataFrame(data=y,index=x,columns=['sine'])

# %%
df.head()
# Out:
#          sine
# 0.0  0.000000
# 0.1  0.099833
# 0.2  0.198669
# 0.3  0.295520
# 0.4  0.389418

# %%
len(df)
# Out:
# 501

# %%
501*0.1
# Out:
# 50.1

# %%
test_point = np.round(len(df)*0.1)

# %%
test_point
# Out:
# 50.0

# %%
test_ind = int(len(df)-test_point)

# %%
test_ind
# Out:
# 451

# %%
train = df.iloc[:test_ind]
test = df.iloc[test_ind:]

# %%
train
# Out:
#           sine
# 0.0   0.000000
# 0.1   0.099833
# 0.2   0.198669
# 0.3   0.295520
# 0.4   0.389418
# ...        ...
# 44.6  0.579164
# 44.7  0.657656
# 44.8  0.729577
# 44.9  0.794208
# 45.0  0.850904
#
# [451 rows x 1 columns]

# %%
test
# Out:
#           sine
# 45.1  0.899097
# 45.2  0.938307
# 45.3  0.968142
# 45.4  0.988304
# 45.5  0.998591
# 45.6  0.998900
# 45.7  0.989229
# 45.8  0.969673
# 45.9  0.940429
# 46.0  0.901788
# 46.1  0.854137
# 46.2  0.797952
# 46.3  0.733794
# 46.4  0.662304
# 46.5  0.584197
# 46.6  0.500252
# 46.7  0.411309
# 46.8  0.318257
# 46.9  0.222024
# 47.0  0.123573
# 47.1  0.023888
# 47.2 -0.076037
# 47.3 -0.175201
# 47.4 -0.272615
# 47.5 -0.367305
# 47.6 -0.458325
# 47.7 -0.544766
# 47.8 -0.625764
# 47.9 -0.700509
# 48.0 -0.768255
# 48.1 -0.828324
# 48.2 -0.880118
# 48.3 -0.923117
# 48.4 -0.956893
# 48.5 -0.981108
# 48.6 -0.995521
# 48.7 -0.999986
# 48.8 -0.994460
# 48.9 -0.978997
# 49.0 -0.953753
# 49.1 -0.918979
# 49.2 -0.875023
# 49.3 -0.822324
# 49.4 -0.761408
# 49.5 -0.692885
# 49.6 -0.617439
# 49.7 -0.535823
# 49.8 -0.448854
# 49.9 -0.357400
# 50.0 -0.262375

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(train)
# Out:
# MinMaxScaler()

# %%
scaled_train = scaler.transform(train)

# %%
scaled_test = scaler.transform(test)

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length = 2 # Length of the output sequences (in number of timesteps)
batch_size = 1 #Number of timeseries samples in each batch
generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=batch_size)

# %%
scaled_train
# Out:
# array([[4.99999116e-01],
#        [5.49916225e-01],
#        [5.99334579e-01],
#        [6.47760405e-01],
#        [6.94709850e-01],
#        [7.39713809e-01],
#        [7.82322618e-01],
#        [8.22110545e-01],
#        [8.58680040e-01],
#        [8.91665714e-01],
#        [9.20737985e-01],
#        [9.45606372e-01],
#        [9.66022399e-01],
#        [9.81782075e-01],
#        [9.92727935e-01],
#        [9.98750612e-01],
#        [2.18042242e-01],
#        [2.60674236e-01],
#        [3.05697486e-01],
#        [3.52662133e-01],
#        [4.01098922e-01],
#        [4.50523890e-01],
#        [5.00443198e-01],
#        [5.50358069e-01],
#        [5.99769769e-01],
#        [6.48184595e-01],
#        [6.95118799e-01],
#        [7.40103433e-01],
#        [7.82689024e-01],
#        [8.22450070e-01],
#        [8.58989293e-01],
#        [8.91941605e-01],
#        [9.20977757e-01],
#        [9.45807630e-01],
#        [9.66183132e-01],
#        [9.81900676e-01],
#        [9.92803220e-01],
#        [9.98781828e-01],
#        [9.99776764e-01],
#        [9.95778087e-01],
#        [9.86825751e-01],
#        [9.73009203e-01],
#        [9.54466495e-01],
#        [9.31382900e-01],
#        [9.03989060e-01],
#        [8.72558686e-01],
#        [8.37405820e-01],
#        [7.98881698e-01],
#        [7.57371240e-01],
#        [7.13289205e-01],
#        [6.67076045e-01],
#        [6.19193508e-01],
#        [5.70120021e-01],
#        [5.20345908e-01],
#        [4.70368497e-01],
#        [4.20687145e-01],
#        [3.71798252e-01],
#        [3.24190300e-01],
#        [2.78338972e-01],
#        [2.34702398e-01],
#        [1.93716581e-01],
#        [1.55791039e-01],
#        [1.21304709e-01],
#        [9.06021693e-02],
#        [6.39901882e-02],
#        [4.17346643e-02],
#        [2.40579672e-02],
#        [1.11367167e-02],
#        [3.10001778e-03],
#        [2.81703720e-05],
#        [1.95186738e-03],
#        [8.85188786e-03],
#        [2.06592891e-02],
#        [3.72560954e-02],
#        [5.84764771e-02],
#        [8.41084070e-02],
#        [1.13895779e-01],
#        [1.47540969e-01],
#        [1.84707803e-01],
#        [2.25024924e-01],
#        [2.68089497e-01],
#        [3.13471233e-01],
#        [3.60716695e-01],
#        [4.09353821e-01],
#        [4.58896644e-01],
#        [5.08850150e-01],
#        [5.58715219e-01],
#        [6.07993616e-01],
#        [6.56192968e-01],
#        [7.02831682e-01],
#        [7.47443761e-01],
#        [7.89583454e-01],
#        [8.28829716e-01],
#        [8.64790412e-01],
#        [8.97106234e-01],
#        [9.25454293e-01]])

# %%
X,y = generator[0]
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.49999912 0.54991622]
# Predict this y:
#  [[0.59933458]]

# %%
length = 10 # Length of the output sequences (in number of timesteps)
generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=1)

# %%
X,y = generator[0]
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.49999912 0.54991622 0.59933458 0.64776041 0.69470985 0.73971381
#  0.78232262 0.82211054 0.85868004 0.89166571]
# Predict this y:
#  [[0.92073798]]

# %%
length = 50
batch_size=1
generator = TimeseriesGenerator(scaled_train,scaled_train,length=length,batch_size=1)

# %%
len(scaled_train)
# Out:
# 451

# %%
len(generator)
# Out:
# 401

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,SimpleRNN,LSTM

# %%
n_featured = 1

# %%
model = Sequential()
model.add(SimpleRNN(50,input_shape=(length,n_featured)))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_2 (SimpleRNN)     (None, 50)                2600
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 2,651
# Trainable params: 2,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit_generator(generator,epochs=5)
# Out:
# Epoch 1/5
# 401/401 [==============================] - 3s 7ms/step - loss: 0.0243
# Epoch 2/5
# 401/401 [==============================] - 3s 7ms/step - loss: 2.3265e-04
# Epoch 3/5
# 401/401 [==============================] - 3s 7ms/step - loss: 1.8700e-04
# Epoch 4/5
# 401/401 [==============================] - 3s 7ms/step - loss: 3.4192e-04
# Epoch 5/5
# 401/401 [==============================] - 3s 7ms/step - loss: 7.0351e-05

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses
# Out:
#        loss
# 0  0.024254
# 1  0.000233
# 2  0.000187
# 3  0.000342
# 4  0.000070

# %%
losses.plot()

# %%
first_eval_batch = scaled_train[-length:]

# %%
first_eval_batch
# Out:
# array([[8.37405820e-01],
#        [7.98881698e-01],
#        [7.57371240e-01],
#        [7.13289205e-01],
#        [6.67076045e-01],
#        [6.19193508e-01],
#        [5.70120021e-01],
#        [5.20345908e-01],
#        [4.70368497e-01],
#        [4.20687145e-01],
#        [3.71798252e-01],
#        [3.24190300e-01],
#        [2.78338972e-01],
#        [2.34702398e-01],
#        [1.93716581e-01],
#        [1.55791039e-01],
#        [1.21304709e-01],
#        [9.06021693e-02],
#        [6.39901882e-02],
#        [4.17346643e-02],
#        [2.40579672e-02],
#        [1.11367167e-02],
#        [3.10001778e-03],
#        [2.81703720e-05],
#        [1.95186738e-03],
#        [8.85188786e-03],
#        [2.06592891e-02],
#        [3.72560954e-02],
#        [5.84764771e-02],
#        [8.41084070e-02],
#        [1.13895779e-01],
#        [1.47540969e-01],
#        [1.84707803e-01],
#        [2.25024924e-01],
#        [2.68089497e-01],
#        [3.13471233e-01],
#        [3.60716695e-01],
#        [4.09353821e-01],
#        [4.58896644e-01],
#        [5.08850150e-01],
#        [5.58715219e-01],
#        [6.07993616e-01],
#        [6.56192968e-01],
#        [7.02831682e-01],
#        [7.47443761e-01],
#        [7.89583454e-01],
#        [8.28829716e-01],
#        [8.64790412e-01],
#        [8.97106234e-01],
#        [9.25454293e-01]])

# %%
first_eval_batch = first_eval_batch.reshape((1,length,n_featured))

# %%
model.predict(first_eval_batch)
# Out:
# array([[0.9440797]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0.94955134])

# %%
test_predictions = []
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1,length,n_featured))

# %%
current_batch
# Out:
# array([[[8.37405820e-01],
#         [7.98881698e-01],
#         [7.57371240e-01],
#         [7.13289205e-01],
#         [6.67076045e-01],
#         [6.19193508e-01],
#         [5.70120021e-01],
#         [5.20345908e-01],
#         [4.70368497e-01],
#         [4.20687145e-01],
#         [3.71798252e-01],
#         [3.24190300e-01],
#         [2.78338972e-01],
#         [2.34702398e-01],
#         [1.93716581e-01],
#         [1.55791039e-01],
#         [1.21304709e-01],
#         [9.06021693e-02],
#         [6.39901882e-02],
#         [4.17346643e-02],
#         [2.40579672e-02],
#         [1.11367167e-02],
#         [3.10001778e-03],
#         [2.81703720e-05],
#         [1.95186738e-03],
#         [8.85188786e-03],
#         [2.06592891e-02],
#         [3.72560954e-02],
#         [5.84764771e-02],
#         [8.41084070e-02],
#         [1.13895779e-01],
#         [1.47540969e-01],
#         [1.84707803e-01],
#         [2.25024924e-01],
#         [2.68089497e-01],
#         [3.13471233e-01],
#         [3.60716695e-01],
#         [4.09353821e-01],
#         [4.58896644e-01],
#         [5.08850150e-01],
#         [5.58715219e-01],
#         [6.07993616e-01],
#         [6.56192968e-01],
#         [7.02831682e-01],
#         [7.47443761e-01],
#         [7.89583454e-01],
#         [8.28829716e-01],
#         [8.64790412e-01],
#         [8.97106234e-01],
#         [9.25454293e-01]]])

# %%
np.append(current_batch[:,1:,:],[[[99]]],axis=1)
# Out:
# array([[[7.98881698e-01],
#         [7.57371240e-01],
#         [7.13289205e-01],
#         [6.67076045e-01],
#         [6.19193508e-01],
#         [5.70120021e-01],
#         [5.20345908e-01],
#         [4.70368497e-01],
#         [4.20687145e-01],
#         [3.71798252e-01],
#         [3.24190300e-01],
#         [2.78338972e-01],
#         [2.34702398e-01],
#         [1.93716581e-01],
#         [1.55791039e-01],
#         [1.21304709e-01],
#         [9.06021693e-02],
#         [6.39901882e-02],
#         [4.17346643e-02],
#         [2.40579672e-02],
#         [1.11367167e-02],
#         [3.10001778e-03],
#         [2.81703720e-05],
#         [1.95186738e-03],
#         [8.85188786e-03],
#         [2.06592891e-02],
#         [3.72560954e-02],
#         [5.84764771e-02],
#         [8.41084070e-02],
#         [1.13895779e-01],
#         [1.47540969e-01],
#         [1.84707803e-01],
#         [2.25024924e-01],
#         [2.68089497e-01],
#         [3.13471233e-01],
#         [3.60716695e-01],
#         [4.09353821e-01],
#         [4.58896644e-01],
#         [5.08850150e-01],
#         [5.58715219e-01],
#         [6.07993616e-01],
#         [6.56192968e-01],
#         [7.02831682e-01],
#         [7.47443761e-01],
#         [7.89583454e-01],
#         [8.28829716e-01],
#         [8.64790412e-01],
#         [8.97106234e-01],
#         [9.25454293e-01],
#         [9.90000000e+01]]])

# %%
test_predictions = []
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1,length,n_featured))

for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
test_predictions
# Out:
# [array([0.9440797], dtype=float32),
#  array([0.9621261], dtype=float32),
#  array([0.9752929], dtype=float32),
#  array([0.9811343], dtype=float32),
#  array([0.98368484], dtype=float32),
#  array([0.97976285], dtype=float32),
#  array([0.97088], dtype=float32),
#  array([0.9578393], dtype=float32),
#  array([0.9386932], dtype=float32),
#  array([0.9155346], dtype=float32),
#  array([0.88830405], dtype=float32),
#  array([0.856768], dtype=float32),
#  array([0.8222087], dtype=float32),
#  array([0.783857], dtype=float32),
#  array([0.74275684], dtype=float32),
#  array([0.69986653], dtype=float32),
#  array([0.65482426], dtype=float32),
#  array([0.607667], dtype=float32),
#  array([0.5595917], dtype=float32),
#  array([0.51011395], dtype=float32),
#  array([0.4596033], dtype=float32),
#  array([0.40903008], dtype=float32),
#  array([0.35828486], dtype=float32),
#  array([0.30785286], dtype=float32),
#  array([0.25867695], dtype=float32),
#  array([0.21113078], dtype=float32),
#  array([0.16589676], dtype=float32),
#  array([0.12369119], dtype=float32),
#  array([0.0849469], dtype=float32),
#  array([0.05031378], dtype=float32),
#  array([0.02049878], dtype=float32),
#  array([-0.00478631], dtype=float32),
#  array([-0.02488], dtype=float32),
#  array([-0.03950568], dtype=float32),
#  array([-0.04956152], dtype=float32),
#  array([-0.05415814], dtype=float32),
#  array([-0.05367656], dtype=float32),
#  array([-0.04909825], dtype=float32),
#  array([-0.03940777], dtype=float32),
#  array([-0.02552703], dtype=float32),
#  array([-0.00789409], dtype=float32),
#  array([0.01455105], dtype=float32),
#  array([0.04040883], dtype=float32),
#  array([0.07001382], dtype=float32),
#  array([0.10410755], dtype=float32),
#  array([0.14140972], dtype=float32),
#  array([0.18266119], dtype=float32),
#  array([0.22791712], dtype=float32),
#  array([0.27590057], dtype=float32),
#  array([0.3271713], dtype=float32)]

# %%
scaled_train
# Out:
# array([[4.99999116e-01],
#        [5.49916225e-01],
#        [5.99334579e-01],
#        [6.47760405e-01],
#        [6.94709850e-01],
#        [7.39713809e-01],
#        [7.82322618e-01],
#        [8.22110545e-01],
#        [8.58680040e-01],
#        [8.91665714e-01],
#        [9.20737985e-01],
#        [9.45606372e-01],
#        [9.66022399e-01],
#        [9.81782075e-01],
#        [9.92727935e-01],
#        [9.98750612e-01],
#        [9.99789928e-01],
#        [9.95835500e-01],
#        [9.86926839e-01],
#        [9.73152957e-01],
#        [9.54651478e-01],
#        [9.31607263e-01],
#        [9.04250562e-01],
#        [8.72854714e-01],
#        [8.37733417e-01],
#        [7.99237589e-01],
#        [7.57751870e-01],
#        [7.13690771e-01],
#        [6.67494535e-01],
#        [6.19624741e-01],
#        [5.70559686e-01],
#        [5.20789614e-01],
#        [4.70811810e-01],
#        [4.21125636e-01],
#        [3.72227539e-01],
#        [3.24606094e-01],
#        [2.78737119e-01],
#        [2.35078919e-01],
#        [1.94067715e-01],
#        [1.56113277e-01],
#        [1.21594831e-01],
#        [9.08572769e-02],
#        [6.42077324e-02],
#        [4.19124713e-02],
#        [2.41942605e-02],
#        [1.12301346e-02],
#        [3.14962674e-03],
#        [3.34747619e-05],
#        [1.91281421e-03],
#        [8.76886734e-03],
#        [2.05331307e-02],
#        [3.70880598e-02],
#        [5.82682430e-02],
#        [8.38620552e-02],
#        [1.13613771e-01],
#        [1.47226122e-01],
#        [1.84363264e-01],
#        [2.24654135e-01],
#        [2.67696162e-01],
#        [3.13059283e-01],
#        [3.60290246e-01],
#        [4.08917133e-01],
#        [4.58454081e-01],
#        [5.08406134e-01],
#        [5.58274186e-01],
#        [6.07559973e-01],
#        [6.55771048e-01],
#        [7.02425701e-01],
#        [7.47057774e-01],
#        [2.81703720e-05],
#        [1.95186738e-03],
#        [8.85188786e-03],
#        [2.06592891e-02],
#        [3.72560954e-02],
#        [5.84764771e-02],
#        [8.41084070e-02],
#        [1.13895779e-01],
#        [1.47540969e-01],
#        [1.84707803e-01],
#        [2.25024924e-01],
#        [2.68089497e-01],
#        [3.13471233e-01],
#        [3.60716695e-01],
#        [4.09353821e-01],
#        [4.58896644e-01],
#        [5.08850150e-01],
#        [5.58715219e-01],
#        [6.07993616e-01],
#        [6.56192968e-01],
#        [7.02831682e-01],
#        [7.47443761e-01],
#        [7.89583454e-01],
#        [8.28829716e-01],
#        [8.64790412e-01],
#        [8.97106234e-01],
#        [9.25454293e-01]])

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test['Predictions'] = true_predictions
# Out:
# c:\users\qadri\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test
# Out:
#           sine  Predictions
# 45.1  0.899097     0.888154
# 45.2  0.938307     0.924247
# 45.3  0.968142     0.950580
# 45.4  0.988304     0.962263
# 45.5  0.998591     0.967364
# 45.6  0.998900     0.959520
# 45.7  0.989229     0.941754
# 45.8  0.969673     0.915673
# 45.9  0.940429     0.877381
# 46.0  0.901788     0.831064
# 46.1  0.854137     0.776604
# 46.2  0.797952     0.713532
# 46.3  0.733794     0.644414
# 46.4  0.662304     0.567711
# 46.5  0.584197     0.485512
# 46.6  0.500252     0.399732
# 46.7  0.411309     0.309648
# 46.8  0.318257     0.215334
# 46.9  0.222024     0.119184
# 47.0  0.123573     0.020230
# 47.1  0.023888    -0.080791
# 47.2 -0.076037    -0.181937
# 47.3 -0.175201    -0.283426
# 47.4 -0.272615    -0.384289
# 47.5 -0.367305    -0.482640
# 47.6 -0.458325    -0.577732
# 47.7 -0.544766    -0.668199
# 47.8 -0.625764    -0.752610
# 47.9 -0.700509    -0.830098
# 48.0 -0.768255    -0.899363
# 48.1 -0.828324    -0.958993
# 48.2 -0.880118    -1.009563
# 48.3 -0.923117    -1.049750
# 48.4 -0.956893    -1.079001
# 48.5 -0.981108    -1.099112
# 48.6 -0.995521    -1.108306
# 48.7 -0.999986    -1.107342
# 48.8 -0.994460    -1.098186
# 48.9 -0.978997    -1.078805
# 49.0 -0.953753    -1.051044
# 49.1 -0.918979    -1.015778
# 49.2 -0.875023    -0.970888
# 49.3 -0.822324    -0.919173
# 49.4 -0.761408    -0.859964
# 49.5 -0.692885    -0.791777
# 49.6 -0.617439    -0.717173
# 49.7 -0.535823    -0.634671
# 49.8 -0.448854    -0.544160
# 49.9 -0.357400    -0.448193
# 50.0 -0.262375    -0.345653

# %%
test.plot(figsize=(12,8))

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=2)

# %%
length=49
generator = TimeseriesGenerator(scaled_train,scaled_train,length=length,batch_size=1)

valid_gen = TimeseriesGenerator(scaled_test, scaled_test,length=length,batch_size=1)

# %%
model = Sequential()
model.add(LSTM(50,input_shape=(length,n_featured)))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')

# %%
model.fit_generator(generator,validation_data=valid_gen,epochs=20,callbacks=[early_stop])
# Out:
# Epoch 1/20
# 402/402 [==============================] - 5s 14ms/step - loss: 0.0127 - val_loss: 2.1292e-04
# Epoch 2/20
# 402/402 [==============================] - 5s 13ms/step - loss: 2.1106e-04 - val_loss: 9.0876e-06
# Epoch 3/20
# 402/402 [==============================] - 5s 14ms/step - loss: 3.1451e-04 - val_loss: 2.0508e-04
# Epoch 4/20
# 402/402 [==============================] - 5s 13ms/step - loss: 2.6714e-04 - val_loss: 2.9335e-04

# %%
test_predictions = []

first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_featured))

for i in range(len(test)):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
true_predictions = scaler.inverse_transform(test_predictions)
test['LSTM'] = true_predictions
test.plot(figsize=(12,8))
# Out:
# c:\users\qadri\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
full_scaler = MinMaxScaler()

# %%
scaled_full_data = full_scaler.fit_transform(df)

# %%
length=50
generator = TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(length, n_featured)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.fit_generator(generator,epochs=6)
# Out:
# Epoch 1/6
# 451/451 [==============================] - 6s 13ms/step - loss: 0.0162
# Epoch 2/6
# 451/451 [==============================] - 6s 13ms/step - loss: 4.1325e-05
# Epoch 3/6
# 451/451 [==============================] - 6s 13ms/step - loss: 4.3341e-05
# Epoch 4/6
# 451/451 [==============================] - 6s 13ms/step - loss: 7.4463e-05
# Epoch 5/6
# 451/451 [==============================] - 6s 13ms/step - loss: 4.8680e-04
# Epoch 6/6
# 451/451 [==============================] - 6s 13ms/step - loss: 4.2803e-05

# %%
forecast = []
first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_featured))

for i in range(len(test)):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
df
# Out:
#           sine
# 0.0   0.000000
# 0.1   0.099833
# 0.2   0.198669
# 0.3   0.295520
# 0.4   0.389418
# ...        ...
# 49.6 -0.617439
# 49.7 -0.535823
# 49.8 -0.448854
# 49.9 -0.357400
# 50.0 -0.262375
#
# [501 rows x 1 columns]

# %%
len(forecast)
# Out:
# 50

# %%
50*0.1
# Out:
# 5.0

# %%
forecast_index = np.arange(50.1,55.1,step=0.1)

# %%
len(forecast_index)
# Out:
# 50

# %%
plt.plot(df.index,df['sine'])
plt.plot(forecast_index,forecast)
